# %% [markdown]
# <a href="https://colab.research.google.com/github/praxacharya/GeometricBrownianMotion/blob/main/INN_ReneWind_Main_Project_LowCode_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## Business Context

# %% [markdown]
# Renewable energy sources play an increasingly important role in the global energy mix, as the effort to reduce the environmental impact of energy production increases.
#
# Out of all the renewable energy alternatives, wind energy is one of the most developed technologies worldwide. The U.S Department of Energy has put together a guide to achieving operational efficiency using predictive maintenance practices.
#
# Predictive maintenance uses sensor information and analysis methods to measure and predict degradation and future component capability. The idea behind predictive maintenance is that failure patterns are predictable and if component failure can be predicted accurately and the component is replaced before it fails, the costs of operation and maintenance will be much lower.
#
# The sensors fitted across different machines involved in the process of energy generation collect data related to various environmental factors (temperature, humidity, wind speed, etc.) and additional features related to various parts of the wind turbine (gearbox, tower, blades, break, etc.).

# %% [markdown]
# ## Objective

# %% [markdown]
# “ReneWind” is a company working on improving the machinery/processes involved in the production of wind energy using machine learning and has collected data of generator failure of wind turbines using sensors. They have shared a ciphered version of the data, as the data collected through sensors is confidential (the type of data collected varies with companies). Data has 40 predictors, 20000 observations in the training set and 5000 in the test set.
#
# The objective is to build various classification models, tune them, and find the best one that will help identify failures so that the generators could be repaired before failing/breaking to reduce the overall maintenance cost.
# The nature of predictions made by the classification model will translate as follows:
#
# - True positives (TP) are failures correctly predicted by the model. These will result in repairing costs.
# - False negatives (FN) are real failures where there is no detection by the model. These will result in replacement costs.
# - False positives (FP) are detections where there is no failure. These will result in inspection costs.
#
# It is given that the cost of repairing a generator is much less than the cost of replacing it, and the cost of inspection is less than the cost of repair.
#
# “1” in the target variables should be considered as “failure” and “0” represents “No failure”.

# %% [markdown]
# ## Data Description

# %% [markdown]
# The data provided is a transformed version of the original data which was collected using sensors.
#
# - Train.csv - To be used for training and tuning of models.
# - Test.csv - To be used only for testing the performance of the final best model.
#
# Both the datasets consist of 40 predictor variables and 1 target variable.

# %% [markdown]
# # **Please read the instructions carefully before starting the project.**
# This is a commented Jupyter IPython Notebook file in which all the instructions and tasks to be performed are mentioned.
# * Blanks '_______' are provided in the notebook that
# needs to be filled with an appropriate code to get the correct result. With every '_______' blank, there is a comment that briefly describes what needs to be filled in the blank space.
# * Identify the task to be performed correctly, and only then proceed to write the required code.
# * Fill the code wherever asked by the commented lines like "# write your code here" or "# complete the code". Running incomplete code may throw error.
# * Please run the codes in a sequential manner from the beginning to avoid any unnecessary errors.
# * Add the results/observations (wherever mentioned) derived from the analysis in the presentation and submit the same.

# %% [markdown]
# # **Installing and Importing the necessary libraries**

# %%
# Installing the libraries with the specified version
# !pip install --no-deps tensorflow==2.18.0 scikit-learn==1.3.2 matplotlib===3.8.3 seaborn==0.13.2 numpy==1.26.4 pandas==2.2.2 -q --user --no-warn-script-location
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.5/615.5 MB 1.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 31.7 MB/s eta 0:00:00

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# Library for data manipulation and analysis.
import pandas as pd
# Fundamental package for scientific computing.
import numpy as np
#splitting datasets into training and testing sets.
from sklearn.model_selection import train_test_split
#Imports tools for data preprocessing including label encoding, one-hot encoding, and standard scaling
from sklearn.preprocessing import LabelEncoder, OneHotEncoder,StandardScaler
#Imports a class for imputing missing values in datasets.
from sklearn.impute import SimpleImputer
#Imports the Matplotlib library for creating visualizations.
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Imports the Seaborn library for statistical data visualization.
import seaborn as sns
# Time related functions.
import time
#Imports functions for evaluating the performance of machine learning models
from sklearn.metrics import confusion_matrix, f1_score,accuracy_score, recall_score, precision_score, classification_report
#Imports metrics from
from sklearn import metrics

#Imports the tensorflow,keras and layers.
import tensorflow
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dense, Input, Dropout,BatchNormalization
from tensorflow.keras import backend

# to suppress unnecessary warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Loading the Data**

# %%
# uncomment and run the following lines for Google Colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/Train.csv")    # Complete the code to import the training data
df_test = pd.read_csv("/content/Test.csv")    # Complete the code to import the test data

# %% [markdown]
# # **Data Overview**

# %% [markdown]
# The initial steps to get an overview of any dataset is to:
# - observe the first few rows of the dataset, to check whether the dataset has been loaded properly or not
# - get information about the number of rows and columns in the dataset
# - find out the data types of the columns to ensure that data is stored in the preferred format and the value of each property is as expected.
# - check the statistical summary of the dataset to get an overview of the numerical columns of the data

# %% [markdown]
# ## Checking the shape of the dataset

# %%
# Checking the number of rows and columns in the training data
df.shape # Complete the code to print the shape of the train data
# Out:
# (20000, 41)

# %%
# Checking the number of rows and columns in the test data
df_test.shape # Complete the code to print the shape of the test data
# Out:
# (5000, 41)

# %%
# let's create a copy of the training data
data = df.copy()

# %%
# let's create a copy of the testing  data
data_test = df_test.copy()

# %% [markdown]
# ## Displaying the first few rows of the dataset

# %%
# let's view the first 5 rows of the data
data.head() # Complete the code to view the first five rows of the train data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -4.464606 -4.679129  3.101546  0.506130 -0.221083 -2.032511 -2.910870
# 1  3.365912  3.653381  0.909671 -1.367528  0.332016  2.358938  0.732600
# 2 -3.831843 -5.824444  0.634031 -2.418815 -1.773827  1.016824 -2.098941
# 3  1.618098  1.888342  7.046143 -1.147285  0.083080 -1.529780  0.207309
# 4 -0.111440  3.872488 -3.758361 -2.982897  3.792714  0.544960  0.205433
#
#          V8        V9       V10  ...       V32       V33        V34       V35  \
# 0  0.050714 -1.522351  3.761892  ...  3.059700 -1.690440   2.846296  2.235198
# 1 -4.332135  0.565695 -0.101080  ... -1.795474  3.032780  -2.467514  1.894599
# 2 -3.173204 -2.081860  5.392621  ... -0.257101  0.803550   4.086219  2.292138
# 3 -2.493629  0.344926  2.118578  ... -3.584425 -2.577474   1.363769  0.622714
# 4  4.848994 -1.854920 -6.220023  ...  8.265896  6.629213 -10.068689  1.222987
#
#         V36       V37       V38       V39       V40  Target
# 0  6.667486  0.443809 -2.369169  2.950578 -3.480324       0
# 1 -2.297780 -1.731048  5.908837 -0.386345  0.616242       0
# 2  5.360850  0.351993  2.940021  3.839160 -4.309402       0
# 3  5.550100 -1.526796  0.138853  3.101430 -1.277378       0
# 4 -3.229763  1.686909 -2.163896 -3.644622  6.510338       0
#
# [5 rows x 41 columns]

# %%
#viewing first 5 rows of the test data
data_test.head() # Complete the code to view the first five rows of the test data
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.613489 -3.819640  2.202302  1.300420 -1.184929 -4.495964 -1.835817
# 1  0.389608 -0.512341  0.527053 -2.576776 -1.016766  2.235112 -0.441301
# 2 -0.874861 -0.640632  4.084202 -1.590454  0.525855 -1.957592 -0.695367
# 3  0.238384  1.458607  4.014528  2.534478  1.196987 -3.117330 -0.924035
# 4  5.828225  2.768260 -1.234530  2.809264 -1.641648 -1.406698  0.568643
#
#          V8        V9       V10  ...       V32       V33       V34       V35  \
# 0  4.722989  1.206140 -0.341909  ...  2.291204 -5.411388  0.870073  0.574479
# 1 -4.405744 -0.332869  1.966794  ... -2.474936  2.493582  0.315165  2.059288
# 2  1.347309 -1.732348  0.466500  ... -1.318888 -2.997464  0.459664  0.619774
# 3  0.269493  1.322436  0.702345  ...  3.517918 -3.074085 -0.284220  0.954576
# 4  0.965043  1.918379 -2.774855  ...  1.773841 -1.501573 -2.226702  4.776830
#
#         V36       V37        V38       V39       V40  Target
# 0  4.157191  1.428093 -10.511342  0.454664 -1.448363       0
# 1  0.683859 -0.485452   5.128350  1.720744 -1.488235       0
# 2  5.631504  1.323512  -1.752154  1.808302  1.675748       0
# 3  3.029331 -1.367198  -3.412140  0.906000 -2.450889       0
# 4 -6.559698 -0.805551  -0.276007 -3.858207 -0.537694       0
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Checking the data types of the columns in the dataset

# %%
# let's check the data types of the columns in the dataset
data.dtypes # Complete the code to view the data types of the columns in the train data
# Out:
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# V29       float64
# V30       float64
# V31       float64
# V32       float64
# V33       float64
# V34       float64
# V35       float64
# V36       float64
# V37       float64
# V38       float64
# V39       float64
# V40       float64
# Target      int64
# dtype: object

# %% [markdown]
# - Converting Target column to float

# %%
data['Target'] = data['Target'].astype(float)

# %% [markdown]
# Now checking for test data

# %%
data_test.dtypes # Complete the code to view the data types of the columns in the test data
# Out:
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# V29       float64
# V30       float64
# V31       float64
# V32       float64
# V33       float64
# V34       float64
# V35       float64
# V36       float64
# V37       float64
# V38       float64
# V39       float64
# V40       float64
# Target      int64
# dtype: object

# %% [markdown]
# Converting Target to float

# %%
data_test['Target'] = data_test['Target'].astype(float)

# %% [markdown]
# ## Checking for duplicate values

# %%
# let's check for duplicate values in the data
data.duplicated().sum() # Complete the code to check for duplicate values in the train data
# Out:
# np.int64(0)

# %% [markdown]
# ## Checking for missing values

# %%
# let's check for missing values in the data
data.isnull().sum()
# Out:
# V1        18
# V2        18
# V3         0
# V4         0
# V5         0
# V6         0
# V7         0
# V8         0
# V9         0
# V10        0
# V11        0
# V12        0
# V13        0
# V14        0
# V15        0
# V16        0
# V17        0
# V18        0
# V19        0
# V20        0
# V21        0
# V22        0
# V23        0
# V24        0
# V25        0
# V26        0
# V27        0
# V28        0
# V29        0
# V30        0
# V31        0
# V32        0
# V33        0
# V34        0
# V35        0
# V36        0
# V37        0
# V38        0
# V39        0
# V40        0
# Target     0
# dtype: int64

# %%
# let's check for missing values in the test data
data_test.isnull().sum() #
# Out:
# V1        5
# V2        6
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# V29       0
# V30       0
# V31       0
# V32       0
# V33       0
# V34       0
# V35       0
# V36       0
# V37       0
# V38       0
# V39       0
# V40       0
# Target    0
# dtype: int64

# %% [markdown]
# ## Statistical summary of the dataset

# %%
# let's view the statistical summary of the numerical columns in the data
data.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  19982.000000  19982.000000  20000.000000  20000.000000  20000.000000
# mean      -0.271996      0.440430      2.484699     -0.083152     -0.053752
# std        3.441625      3.150784      3.388963      3.431595      2.104801
# min      -11.876451    -12.319951    -10.708139    -15.082052     -8.603361
# 25%       -2.737146     -1.640674      0.206860     -2.347660     -1.535607
# 50%       -0.747917      0.471536      2.255786     -0.135241     -0.101952
# 75%        1.840112      2.543967      4.566165      2.130615      1.340480
# max       15.493002     13.089269     17.090919     13.236381      8.133797
#
#                  V6            V7            V8            V9           V10  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean      -0.995443     -0.879325     -0.548195     -0.016808     -0.012998
# std        2.040970      1.761626      3.295756      2.160568      2.193201
# min      -10.227147     -7.949681    -15.657561     -8.596313     -9.853957
# 25%       -2.347238     -2.030926     -2.642665     -1.494973     -1.411212
# 50%       -1.000515     -0.917179     -0.389085     -0.067597      0.100973
# 75%        0.380330      0.223695      1.722965      1.409203      1.477045
# max        6.975847      8.006091     11.679495      8.137580      8.108472
#
#        ...           V32           V33           V34           V35  \
# count  ...  20000.000000  20000.000000  20000.000000  20000.000000
# mean   ...      0.303799      0.049825     -0.462702      2.229620
# std    ...      5.500400      3.575285      3.183841      2.937102
# min    ...    -19.876502    -16.898353    -17.985094    -15.349803
# 25%    ...     -3.420469     -2.242857     -2.136984      0.336191
# 50%    ...      0.052073     -0.066249     -0.255008      2.098633
# 75%    ...      3.761722      2.255134      1.436935      4.064358
# max    ...     23.633187     16.692486     14.358213     15.291065
#
#                 V36           V37           V38           V39           V40  \
# count  20000.000000  20000.000000  20000.000000  20000.000000  20000.000000
# mean       1.514809      0.011316     -0.344025      0.890653     -0.875630
# std        3.800860      1.788165      3.948147      1.753054      3.012155
# min      -14.833178     -5.478350    -17.375002     -6.438880    -11.023935
# 25%       -0.943809     -1.255819     -2.987638     -0.272250     -2.940193
# 50%        1.566526     -0.128435     -0.316849      0.919261     -0.920806
# 75%        3.983939      1.175533      2.279399      2.057540      1.119897
# max       19.329576      7.467006     15.289923      7.759877     10.654265
#
#              Target
# count  20000.000000
# mean       0.055500
# std        0.228959
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 41 columns]

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ## Univariate analysis

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data= data, x= feature, ax= ax_hist2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %% [markdown]
# ### Variables V1 to V29

# %%
for feature in df.columns:
    histogram_boxplot(df, feature, figsize=(12, 7), kde=False, bins=None)

# %% [markdown]
# ### Checking the distrubution of Target variable

# %%
# For train data
df["Target"].value_counts(1)
# Out:
# Target
# 0    0.9445
# 1    0.0555
# Name: proportion, dtype: float64

# %%
# For test data
df_test["Target"].value_counts(1) # Complete the code to display the proportion of the target variable in the test data
# Out:
# Target
# 0    0.9436
# 1    0.0564
# Name: proportion, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Correlation Check

# %%
cols_list = df.select_dtypes(include=np.number).columns.tolist()
cols_list.remove("Target")

plt.figure(figsize=(20, 20))
sns.heatmap(
    df[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral"
)
plt.show()

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ## Data Preparation for Modeling

# %%
# Dividing train data into X and y
X = data.drop(columns = ["Target"] , axis=1) # Complete the code to remove the column named 'Target'
y = data["Target"] # Complete the code to select the column named 'Target'

# %% [markdown]
# **Since we already have a separate test set, we don't need to divide data into train, valiation and test**

# %%
# Splitting data into training and validation set:

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=0.2, random_state=1, stratify=y # Complete the code to define the test size
)

# %%
# Checking the number of rows and columns in the X_train data
X_train.shape
# Out:
# (16000, 40)

# %%
# Checking the number of rows and columns in the X_val data
X_val.shape
# Out:
# (4000, 40)

# %%
# Dividing test data into X_test and y_test
X_test = data_test.drop(columns = ['Target'] , axis= 1) # Complete the code to remove the target column
y_test = data_test["Target"] # Complete the code to select the target column

# %%
# Checking the number of rows and columns in the X_test data
X_test.shape
# Out:
# (5000, 40)

# %% [markdown]
# ## Missing Value Imputation

# %% [markdown]
# - There were few missing values in V1 and V2, we will impute them using the median.
# - And to avoid data leakage we will impute missing values after splitting train data into train and validation sets.

# %%
imputer = SimpleImputer(strategy="median")

# %%
imputer = SimpleImputer(strategy="median")

# %%
# Prakash code

X_train = pd.DataFrame(imputer.fit_transform(X_train), columns=X_train.columns, index=X_train.index)
X_val   = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns, index=X_val.index)
X_test  = pd.DataFrame(imputer.transform(X_test), columns=X_test.columns, index=X_test.index)

# %%
X_train.isnull().sum()

X_train.isnull().sum()

X_val.isnull().sum()
# Out:
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64

# %%
# Checking that no column has missing values in train or test sets
print(X_train.isna().sum())
print("-" * 30)
print(X_val.isna().sum())
print("-" * 30)
print(X_test.isna().sum())
# Out:
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64
# ------------------------------
# V1     0
# V2     0
# V3     0
# V4     0
# V5     0
# V6     0
# V7     0
# V8     0
# V9     0
# V10    0
# V11    0
# V12    0
# V13    0
# V14    0
# V15    0
# V16    0
# V17    0
# V18    0
# V19    0
# V20    0
# V21    0
# V22    0
# V23    0
# V24    0
# V25    0
# V26    0
# V27    0
# V28    0
# V29    0
# V30    0
# V31    0
# V32    0
# V33    0
# V34    0
# V35    0
# V36    0
# V37    0
# V38    0
# V39    0
# V40    0
# dtype: int64

# %%
y_train = y_train.values.reshape(-1, 1)
y_val = y_val.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Select only numeric columns (excluding target)
cols_list = df.select_dtypes(include=np.number).columns.tolist()
cols_list.remove("Target")

# Drop rows with missing values (to avoid imputation)
df_pca = df[cols_list + ["Target"]].dropna()

# Separate features and target
X = df_pca[cols_list]
y = df_pca["Target"]

# Standardize the features for PCA
X_scaled = StandardScaler().fit_transform(X)

# Perform PCA to reduce to 2D
pca = PCA(n_components=2)
pca_result = pca.fit_transform(X_scaled)

# Plot
plt.figure(figsize=(10,7))
sns.scatterplot(
    x=pca_result[:, 0],
    y=pca_result[:, 1],
    hue=y,
    palette="coolwarm",
    alpha=0.7,
    s=60
)
plt.title("PCA Projection (2D) - Colored by Target")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.legend(title="Target")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer # Import SimpleImputer

# Create a clean copy (drop rows with NaNs in numeric columns)
cols_list = df.select_dtypes(include=np.number).columns.tolist()
cols_list.remove("Target")
df_rf = df[cols_list + ["Target"]]

# Impute missing values in df_rf before splitting
imputer_rf = SimpleImputer(strategy="median")
df_rf_imputed = pd.DataFrame(imputer_rf.fit_transform(df_rf), columns=df_rf.columns, index=df_rf.index)

X_rf = df_rf_imputed[cols_list]
y_rf = df_rf_imputed["Target"]

# Fit a quick Random Forest for feature importance exploration
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_rf, y_rf)

# Collect feature importances
importances = pd.DataFrame({
    "Feature": cols_list,
    "Importance": rf.feature_importances_
}).sort_values(by="Importance", ascending=False)

# Plot
plt.figure(figsize=(10, 8))
sns.barplot(y="Feature", x="Importance", data=importances.head(20), palette="viridis")
plt.title("Top 20 Features Driving Target (Random Forest Importance)")
plt.xlabel("Relative Importance")
# Out:
# Text(0.5, 0, 'Relative Importance')

# %% [markdown]
# # **Model Building**

# %%
# Take the top few correlated variables from previous correlation heatmap
corr = df[cols_list + ["Target"]].corr()["Target"].abs().sort_values(ascending=False)
top_features = corr[1:6].index.tolist()  # exclude Target itself

# Drop missing values
df_pair = df[top_features + ["Target"]].dropna()

# Pairplot
sns.pairplot(df_pair, hue="Target", diag_kind="kde", palette="coolwarm")
plt.suptitle("Pairwise Feature Relationships Colored by Target", y=1.02)
plt.show()

# %% [markdown]
# ## Model Evaluation Criterion

# %% [markdown]
# - Write down the metric of choice with rationale here

# %% [markdown]
# **We are now done with pre-processing and evaluation criterion, so let's start building the model.**

# %% [markdown]
# ## Utility Functions

# %%
def plot(history, name):
    """
    Function to plot loss/accuracy

    history: an object which stores the metrics and losses.
    name: can be one of Loss or Accuracy
    """
    fig, ax = plt.subplots() #Creating a subplot with figure and axes.
    plt.plot(history.history[name]) #Plotting the train accuracy or train loss
    plt.plot(history.history['val_'+name]) #Plotting the validation accuracy or validation loss

    plt.title('Model ' + name.capitalize()) #Defining the title of the plot.
    plt.ylabel(name.capitalize()) #Capitalizing the first letter.
    plt.xlabel('Epoch') #Defining the label for the x-axis.
    fig.legend(['Train', 'Validation'], loc="outside right upper") #Defining the legend, loc controls the position of the legend.

# %%
# defining a function to compute different metrics to check performance of a classification model built using statsmodels
def model_performance_classification(
    model, predictors, target, threshold=0.5
):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    threshold: threshold for classifying the observation as class 1
    """

    # checking which probabilities are greater than threshold
    pred = model.predict(predictors) > threshold
    # pred_temp = model.predict(predictors) > threshold
    # # rounding off the above values to get classes
    # pred = np.round(pred_temp)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred, average='macro')  # to compute Recall
    precision = precision_score(target, pred, average='macro')  # to compute Precision
    f1 = f1_score(target, pred, average='macro')  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {"Accuracy": acc, "Recall": recall, "Precision": precision, "F1 Score": f1,}, index = [0]
    )

    return df_perf

# %% [markdown]
# ## Initial Model Building (Model 0)

# %% [markdown]
# - Let's start with a neural network consisting of
#   - just one hidden layer of 7 neurons respectively
#   - activation function of ReLU.
#   - SGD as the optimizer

# %%
# defining the batch size and # epochs upfront as we'll be using the same values for all models
epochs = 50    # Complete the code to enter the number of epochs to be used in all models
batch_size = 32    # Complete the code to enter the batch size to be used in all models

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_0 = Sequential()
model_0.add(Dense( 64 ,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and the activation function
model_0.add(Dense( 1 ,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_0.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,689 (10.50 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_0.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_0.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.3871 - loss: 0.2315 - val_Recall: 0.6982 - val_loss: 0.0964
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6330 - loss: 0.0906 - val_Recall: 0.7523 - val_loss: 0.0834
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7444 - loss: 0.0700 - val_Recall: 0.7793 - val_loss: 0.0782
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7504 - loss: 0.0711 - val_Recall: 0.7883 - val_loss: 0.0747
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.7748 - loss: 0.0654 - val_Recall: 0.7793 - val_loss: 0.0716
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8018 - loss: 0.0603 - val_Recall: 0.8018 - val_loss: 0.0711
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8004 - loss: 0.0633 - val_Recall: 0.8018 - val_loss: 0.0690
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8110 - loss: 0.0591 - val_Recall: 0.8063 - val_loss: 0.0676
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8261 - loss: 0.0563 - val_Recall: 0.8108 - val_loss: 0.0671
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8272 - loss: 0.0535 - val_Recall: 0.8063 - val_loss: 0.0659
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8468 - loss: 0.0502 - val_Recall: 0.8108 - val_loss: 0.0652
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8307 - loss: 0.0538 - val_Recall: 0.8063 - val_loss: 0.0649
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - Recall: 0.8194 - loss: 0.0590 - val_Recall: 0.8198 - val_loss: 0.0644
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8041 - loss: 0.0581 - val_Recall: 0.8108 - val_loss: 0.0637
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8465 - loss: 0.0532 - val_Recall: 0.8153 - val_loss: 0.0636
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8287 - loss: 0.0523 - val_Recall: 0.8153 - val_loss: 0.0634
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.8273 - loss: 0.0539 - val_Recall: 0.8153 - val_loss: 0.0633
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - Recall: 0.8596 - loss: 0.0460 - val_Recall: 0.8288 - val_loss: 0.0636
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8339 - loss: 0.0552 - val_Recall: 0.8153 - val_loss: 0.0635
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8356 - loss: 0.0495 - val_Recall: 0.8288 - val_loss: 0.0623
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8410 - loss: 0.0486 - val_Recall: 0.8198 - val_loss: 0.0624
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8686 - loss: 0.0416 - val_Recall: 0.8333 - val_loss: 0.0626
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8351 - loss: 0.0513 - val_Recall: 0.8198 - val_loss: 0.0625
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8330 - loss: 0.0524 - val_Recall: 0.8153 - val_loss: 0.0621
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8460 - loss: 0.0462 - val_Recall: 0.8153 - val_loss: 0.0615
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8669 - loss: 0.0429 - val_Recall: 0.8288 - val_loss: 0.0615
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8479 - loss: 0.0455 - val_Recall: 0.8333 - val_loss: 0.0609
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8555 - loss: 0.0443 - val_Recall: 0.8333 - val_loss: 0.0609
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8399 - loss: 0.0524 - val_Recall: 0.8333 - val_loss: 0.0612
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8576 - loss: 0.0434 - val_Recall: 0.8243 - val_loss: 0.0618
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8452 - loss: 0.0445 - val_Recall: 0.8243 - val_loss: 0.0611
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8373 - loss: 0.0542 - val_Recall: 0.8288 - val_loss: 0.0603
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8565 - loss: 0.0470 - val_Recall: 0.8333 - val_loss: 0.0606
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8529 - loss: 0.0468 - val_Recall: 0.8333 - val_loss: 0.0606
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8507 - loss: 0.0437 - val_Recall: 0.8288 - val_loss: 0.0604
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8519 - loss: 0.0428 - val_Recall: 0.8333 - val_loss: 0.0605
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8677 - loss: 0.0420 - val_Recall: 0.8378 - val_loss: 0.0600
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8613 - loss: 0.0411 - val_Recall: 0.8333 - val_loss: 0.0605
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - Recall: 0.8721 - loss: 0.0397 - val_Recall: 0.8378 - val_loss: 0.0602
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - Recall: 0.8347 - loss: 0.0519 - val_Recall: 0.8333 - val_loss: 0.0604
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - Recall: 0.8789 - loss: 0.0406 - val_Recall: 0.8333 - val_loss: 0.0608
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8351 - loss: 0.0559 - val_Recall: 0.8333 - val_loss: 0.0610
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8616 - loss: 0.0416 - val_Recall: 0.8378 - val_loss: 0.0600
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8807 - loss: 0.0401 - val_Recall: 0.8333 - val_loss: 0.0609
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8494 - loss: 0.0472 - val_Recall: 0.8288 - val_loss: 0.0603
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8785 - loss: 0.0380 - val_Recall: 0.8378 - val_loss: 0.0605
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8747 - loss: 0.0376 - val_Recall: 0.8333 - val_loss: 0.0598
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8666 - loss: 0.0425 - val_Recall: 0.8333 - val_loss: 0.0598
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.8717 - loss: 0.0442 - val_Recall: 0.8288 - val_loss: 0.0607
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8870 - loss: 0.0359 - val_Recall: 0.8243 - val_loss: 0.0597

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  79.25527000427246

# %%
plot(history,'loss')

# %%
model_0_train_perf = model_performance_classification(model_0, X_train, y_train)
model_0_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.991875  0.933162    0.98845  0.958935

# %%
model_0_val_perf = model_performance_classification(model_0,X_val,y_val)
model_0_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.98925  0.911633   0.984191    0.9446

# %% [markdown]
# Let's check the classification reports.

# %%
y_train_pred_0 = model_0.predict(X_train)
y_val_pred_0 = model_0.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("Classification Report - Train data Model_0",end="\n\n")
cr_train_model_0 = classification_report(y_train,y_train_pred_0>0.5)
print(cr_train_model_0)
# Out:
# Classification Report - Train data Model_0
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       0.98      0.87      0.92       888
#
#     accuracy                           0.99     16000
#    macro avg       0.99      0.93      0.96     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_0",end="\n\n")
cr_val_model_0 = classification_report(y_val,y_val_pred_0>0.5)
print(cr_val_model_0)
# Out:
# Classification Report - Validation data Model_0
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      3778
#          1.0       0.98      0.82      0.89       222
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.91      0.94      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# # **Model Performance Improvement**

# %% [markdown]
# ## Model 1

# %% [markdown]
# - Let's try adding another layer to see if we can improve our model's performance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_1 = Sequential()
model_1.add(Dense( 128 ,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_1.add(Dense( 64,activation="relu")) # Complete the code to define the number of neurons and activation function
model_1.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_1.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 128)            │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,569 (53.00 KB)
#  Trainable params: 13,569 (53.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_1.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_1.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.4428 - loss: 0.1649 - val_Recall: 0.6937 - val_loss: 0.0898
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.6727 - loss: 0.0852 - val_Recall: 0.7477 - val_loss: 0.0770
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7370 - loss: 0.0666 - val_Recall: 0.7838 - val_loss: 0.0709
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - Recall: 0.7833 - loss: 0.0631 - val_Recall: 0.8108 - val_loss: 0.0689
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.8218 - loss: 0.0577 - val_Recall: 0.8018 - val_loss: 0.0655
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8325 - loss: 0.0523 - val_Recall: 0.8333 - val_loss: 0.0659
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8444 - loss: 0.0483 - val_Recall: 0.8153 - val_loss: 0.0645
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8384 - loss: 0.0539 - val_Recall: 0.8018 - val_loss: 0.0623
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8311 - loss: 0.0467 - val_Recall: 0.8288 - val_loss: 0.0605
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8527 - loss: 0.0479 - val_Recall: 0.8198 - val_loss: 0.0598
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8733 - loss: 0.0439 - val_Recall: 0.8378 - val_loss: 0.0598
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8614 - loss: 0.0406 - val_Recall: 0.8378 - val_loss: 0.0585
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8693 - loss: 0.0433 - val_Recall: 0.8423 - val_loss: 0.0575
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8724 - loss: 0.0410 - val_Recall: 0.8423 - val_loss: 0.0576
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8842 - loss: 0.0382 - val_Recall: 0.8423 - val_loss: 0.0573
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8653 - loss: 0.0426 - val_Recall: 0.8468 - val_loss: 0.0576
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.8847 - loss: 0.0375 - val_Recall: 0.8468 - val_loss: 0.0571
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8584 - loss: 0.0423 - val_Recall: 0.8468 - val_loss: 0.0571
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8691 - loss: 0.0404 - val_Recall: 0.8423 - val_loss: 0.0574
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8770 - loss: 0.0394 - val_Recall: 0.8468 - val_loss: 0.0578
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8787 - loss: 0.0376 - val_Recall: 0.8468 - val_loss: 0.0573
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8896 - loss: 0.0362 - val_Recall: 0.8604 - val_loss: 0.0578
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8818 - loss: 0.0342 - val_Recall: 0.8468 - val_loss: 0.0565
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.8858 - loss: 0.0353 - val_Recall: 0.8559 - val_loss: 0.0572
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - Recall: 0.8913 - loss: 0.0329 - val_Recall: 0.8468 - val_loss: 0.0569
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9008 - loss: 0.0319 - val_Recall: 0.8514 - val_loss: 0.0569
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8854 - loss: 0.0362 - val_Recall: 0.8423 - val_loss: 0.0573
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8745 - loss: 0.0368 - val_Recall: 0.8604 - val_loss: 0.0563
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8928 - loss: 0.0321 - val_Recall: 0.8514 - val_loss: 0.0573
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8964 - loss: 0.0327 - val_Recall: 0.8604 - val_loss: 0.0578
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8803 - loss: 0.0329 - val_Recall: 0.8649 - val_loss: 0.0568
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8743 - loss: 0.0356 - val_Recall: 0.8423 - val_loss: 0.0588
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8955 - loss: 0.0330 - val_Recall: 0.8559 - val_loss: 0.0571
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8897 - loss: 0.0335 - val_Recall: 0.8559 - val_loss: 0.0571
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9155 - loss: 0.0259 - val_Recall: 0.8739 - val_loss: 0.0581
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9065 - loss: 0.0291 - val_Recall: 0.8559 - val_loss: 0.0590
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9028 - loss: 0.0286 - val_Recall: 0.8739 - val_loss: 0.0566
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9031 - loss: 0.0281 - val_Recall: 0.8694 - val_loss: 0.0573
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9104 - loss: 0.0287 - val_Recall: 0.8694 - val_loss: 0.0569
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9135 - loss: 0.0247 - val_Recall: 0.8739 - val_loss: 0.0589
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9065 - loss: 0.0259 - val_Recall: 0.8604 - val_loss: 0.0589
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9009 - loss: 0.0284 - val_Recall: 0.8694 - val_loss: 0.0572
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9078 - loss: 0.0279 - val_Recall: 0.8739 - val_loss: 0.0583
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - Recall: 0.9055 - loss: 0.0291 - val_Recall: 0.8604 - val_loss: 0.0587
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.9062 - loss: 0.0257 - val_Recall: 0.8604 - val_loss: 0.0586
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8938 - loss: 0.0303 - val_Recall: 0.8604 - val_loss: 0.0586
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.9035 - loss: 0.0274 - val_Recall: 0.8559 - val_loss: 0.0603
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8995 - loss: 0.0264 - val_Recall: 0.8694 - val_loss: 0.0572
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - Recall: 0.8860 - loss: 0.0288 - val_Recall: 0.8649 - val_loss: 0.0586
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9074 - loss: 0.0262 - val_Recall: 0.8649 - val_loss: 0.0577

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  87.09777426719666

# %%
plot(history,'loss')

# %%
model_1_train_perf = model_performance_classification(model_1,X_train,y_train)
model_1_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.994313  0.950881   0.994653  0.971623

# %%
model_1_val_perf = model_performance_classification(model_1,X_val,y_val)
model_1_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0     0.991  0.931638   0.980903  0.954768

# %%
y_train_pred_1 = model_1.predict(X_train)
y_val_pred_1 = model_1.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("Classification Report - Train data Model_1", end="\n\n")
cr_train_model_1 = classification_report(y_train,y_train_pred_1 > 0.5)
print(cr_train_model_1)
# Out:
# Classification Report - Train data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       1.00      0.90      0.95       888
#
#     accuracy                           0.99     16000
#    macro avg       0.99      0.95      0.97     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_1", end="\n\n")
cr_val_model_1 = classification_report(y_val,y_val_pred_1 > 0.5)
print(cr_val_model_1)
# Out:
# Classification Report - Validation data Model_1
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3778
#          1.0       0.97      0.86      0.91       222
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.93      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 2

# %% [markdown]
# To introduce Regularization in our model, let's set the dropout to 50% after adding the first hidden layer. This step will randomly drop 50% of the neurons before proceeding to the next layer, reducing overfitting.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
from tensorflow.keras.layers import Dropout
model_2 = Sequential()
model_2.add(Dense(128,activation="relu",input_dim=X_train.shape[1]))  # Complete the code to define the number of neurons and activation function
model_2.add(Dropout(0.5)) # Complete the code to define the dropout rate
model_2.add(Dense(64,activation = "relu")) # Complete the code to define the number of neurons and activation function
model_2.add(Dense(32,activation = "relu")) # Complete the code to define the number of neurons and activation function
model_2.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 128)            │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,617 (61.00 KB)
#  Trainable params: 15,617 (61.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
model_2.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall'])

# %%
start = time.time()
history = model_2.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.0592 - loss: 0.2383 - val_Recall: 0.4820 - val_loss: 0.1119
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - Recall: 0.3917 - loss: 0.1320 - val_Recall: 0.6937 - val_loss: 0.0936
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - Recall: 0.5238 - loss: 0.1182 - val_Recall: 0.7207 - val_loss: 0.0845
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - Recall: 0.5830 - loss: 0.0983 - val_Recall: 0.7252 - val_loss: 0.0802
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.6219 - loss: 0.0968 - val_Recall: 0.7613 - val_loss: 0.0751
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.6847 - loss: 0.0947 - val_Recall: 0.7658 - val_loss: 0.0723
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7051 - loss: 0.0873 - val_Recall: 0.7838 - val_loss: 0.0691
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7120 - loss: 0.0769 - val_Recall: 0.7838 - val_loss: 0.0685
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7130 - loss: 0.0792 - val_Recall: 0.7928 - val_loss: 0.0655
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7565 - loss: 0.0771 - val_Recall: 0.8018 - val_loss: 0.0625
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7473 - loss: 0.0746 - val_Recall: 0.8018 - val_loss: 0.0633
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7522 - loss: 0.0708 - val_Recall: 0.8063 - val_loss: 0.0633
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7599 - loss: 0.0748 - val_Recall: 0.8153 - val_loss: 0.0609
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7775 - loss: 0.0695 - val_Recall: 0.8198 - val_loss: 0.0600
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7843 - loss: 0.0627 - val_Recall: 0.8288 - val_loss: 0.0594
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7575 - loss: 0.0670 - val_Recall: 0.8288 - val_loss: 0.0579
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7938 - loss: 0.0646 - val_Recall: 0.8243 - val_loss: 0.0594
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8111 - loss: 0.0618 - val_Recall: 0.8243 - val_loss: 0.0577
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.7953 - loss: 0.0633 - val_Recall: 0.8243 - val_loss: 0.0587
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - Recall: 0.8126 - loss: 0.0590 - val_Recall: 0.8333 - val_loss: 0.0572
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.7901 - loss: 0.0562 - val_Recall: 0.8288 - val_loss: 0.0572
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8097 - loss: 0.0584 - val_Recall: 0.8468 - val_loss: 0.0552
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.7906 - loss: 0.0624 - val_Recall: 0.8288 - val_loss: 0.0568
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8084 - loss: 0.0566 - val_Recall: 0.8378 - val_loss: 0.0560
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8315 - loss: 0.0529 - val_Recall: 0.8423 - val_loss: 0.0552
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8333 - loss: 0.0512 - val_Recall: 0.8514 - val_loss: 0.0554
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8054 - loss: 0.0640 - val_Recall: 0.8468 - val_loss: 0.0563
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8167 - loss: 0.0505 - val_Recall: 0.8514 - val_loss: 0.0544
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8096 - loss: 0.0584 - val_Recall: 0.8468 - val_loss: 0.0549
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8232 - loss: 0.0494 - val_Recall: 0.8559 - val_loss: 0.0535
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8548 - loss: 0.0466 - val_Recall: 0.8468 - val_loss: 0.0534
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8398 - loss: 0.0485 - val_Recall: 0.8514 - val_loss: 0.0529
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8467 - loss: 0.0492 - val_Recall: 0.8468 - val_loss: 0.0533
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8435 - loss: 0.0466 - val_Recall: 0.8468 - val_loss: 0.0539
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8386 - loss: 0.0503 - val_Recall: 0.8514 - val_loss: 0.0535
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8451 - loss: 0.0484 - val_Recall: 0.8559 - val_loss: 0.0528
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - Recall: 0.8518 - loss: 0.0492 - val_Recall: 0.8559 - val_loss: 0.0526
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.8221 - loss: 0.0540 - val_Recall: 0.8559 - val_loss: 0.0528
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - Recall: 0.8544 - loss: 0.0497 - val_Recall: 0.8559 - val_loss: 0.0530
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8377 - loss: 0.0485 - val_Recall: 0.8559 - val_loss: 0.0533
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8270 - loss: 0.0510 - val_Recall: 0.8514 - val_loss: 0.0550
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8517 - loss: 0.0460 - val_Recall: 0.8468 - val_loss: 0.0537
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8563 - loss: 0.0481 - val_Recall: 0.8694 - val_loss: 0.0528
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8490 - loss: 0.0467 - val_Recall: 0.8649 - val_loss: 0.0529
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8581 - loss: 0.0451 - val_Recall: 0.8559 - val_loss: 0.0528
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8586 - loss: 0.0461 - val_Recall: 0.8649 - val_loss: 0.0534
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.8478 - loss: 0.0492 - val_Recall: 0.8559 - val_loss: 0.0534
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8630 - loss: 0.0408 - val_Recall: 0.8649 - val_loss: 0.0534
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8638 - loss: 0.0391 - val_Recall: 0.8514 - val_loss: 0.0542
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8505 - loss: 0.0460 - val_Recall: 0.8559 - val_loss: 0.0544

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  103.73987817764282

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_2 on training and validation data respectively.

# %%
model_2_train_perf = model_performance_classification(model_2,X_train,y_train)
model_2_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.993125  0.942833   0.991025  0.965525

# %%
model_2_val_perf = model_performance_classification(model_2,X_val,y_val)
model_2_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.99075  0.927266   0.982974  0.953196

# %%
y_train_pred_2 = model_2.predict(X_train)
y_val_pred_2 = model_2.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# Lets check the classification report of model_2 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_2 = classification_report(y_train,y_train_pred_2 > 0.5)
print(cr_train_model_2)
# Out:
# Classification Report - Train data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00     15112
#          1.0       0.99      0.89      0.93       888
#
#     accuracy                           0.99     16000
#    macro avg       0.99      0.94      0.97     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_2 = classification_report(y_val , y_val_pred_2 > 0.5)
print(cr_val_model_2)
# Out:
# Classification Report - Validation data Model_2
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3778
#          1.0       0.97      0.86      0.91       222
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.93      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 3

# %% [markdown]
# As we have are dealing with an imbalance in class distribution, we should also be using class weights to allow the model to give proportionally more importance to the minority class.

# %%
# Calculate class weights for imbalanced dataset
cw = (y_train.shape[0]) / np.bincount(y_train.astype(int).flatten())

# Create a dictionary mapping class indices to their respective class weights
cw_dict = {}
for i in range(cw.shape[0]):
    cw_dict[i] = cw[i]

cw_dict
# Out:
# {0: np.float64(1.0587612493382743), 1: np.float64(18.01801801801802)}

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
model_3 = Sequential()
model_3.add(Dense(128,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_3.add(Dropout(0.4)) # Complete the code to define the dropout rate
model_3.add(Dense(64,activation="relu")) # Complete the code to define the number of neurons and activation function
model_3.add(Dense(32, activation = "relu")) # Complete the code to define the number of neurons and activation function
model_3.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_3.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,617 (61.00 KB)
#  Trainable params: 15,617 (61.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.SGD()   # defining SGD as the optimizer to be used
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_3.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_3.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs,class_weight=cw_dict)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - Recall: 0.7850 - loss: 0.8648 - val_Recall: 0.8694 - val_loss: 0.1619
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8555 - loss: 0.5643 - val_Recall: 0.8739 - val_loss: 0.1428
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8833 - loss: 0.4732 - val_Recall: 0.8829 - val_loss: 0.1312
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - Recall: 0.8903 - loss: 0.4906 - val_Recall: 0.8829 - val_loss: 0.1661
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8829 - loss: 0.4619 - val_Recall: 0.8829 - val_loss: 0.1396
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8964 - loss: 0.4254 - val_Recall: 0.8874 - val_loss: 0.1629
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9098 - loss: 0.3866 - val_Recall: 0.8874 - val_loss: 0.1380
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9097 - loss: 0.3377 - val_Recall: 0.8829 - val_loss: 0.1423
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9194 - loss: 0.3310 - val_Recall: 0.8919 - val_loss: 0.1379
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.8824 - loss: 0.3830 - val_Recall: 0.8784 - val_loss: 0.1148
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8977 - loss: 0.3525 - val_Recall: 0.8829 - val_loss: 0.1446
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - Recall: 0.8969 - loss: 0.3609 - val_Recall: 0.8829 - val_loss: 0.1343
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - Recall: 0.9093 - loss: 0.3595 - val_Recall: 0.8919 - val_loss: 0.1392
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - Recall: 0.9219 - loss: 0.3018 - val_Recall: 0.8919 - val_loss: 0.1585
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - Recall: 0.9129 - loss: 0.3275 - val_Recall: 0.9009 - val_loss: 0.1430
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9186 - loss: 0.3031 - val_Recall: 0.8919 - val_loss: 0.1259
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9138 - loss: 0.3369 - val_Recall: 0.8829 - val_loss: 0.1337
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9099 - loss: 0.3466 - val_Recall: 0.8829 - val_loss: 0.1379
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9181 - loss: 0.3109 - val_Recall: 0.8874 - val_loss: 0.1094
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9076 - loss: 0.3603 - val_Recall: 0.8874 - val_loss: 0.1138
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9161 - loss: 0.3210 - val_Recall: 0.8919 - val_loss: 0.1456
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9211 - loss: 0.2959 - val_Recall: 0.8919 - val_loss: 0.1248
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.9132 - loss: 0.3083 - val_Recall: 0.8919 - val_loss: 0.1173
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9109 - loss: 0.3315 - val_Recall: 0.8964 - val_loss: 0.1496
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.8843 - loss: 0.3772 - val_Recall: 0.8919 - val_loss: 0.1254
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9204 - loss: 0.2954 - val_Recall: 0.8874 - val_loss: 0.1237
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9230 - loss: 0.2900 - val_Recall: 0.8919 - val_loss: 0.1201
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9149 - loss: 0.3149 - val_Recall: 0.8829 - val_loss: 0.1331
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9121 - loss: 0.3062 - val_Recall: 0.8919 - val_loss: 0.1495
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9233 - loss: 0.2903 - val_Recall: 0.8874 - val_loss: 0.1237
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9218 - loss: 0.3023 - val_Recall: 0.8964 - val_loss: 0.1233
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.9214 - loss: 0.3025 - val_Recall: 0.8874 - val_loss: 0.1136
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9267 - loss: 0.2765 - val_Recall: 0.8919 - val_loss: 0.1223
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9218 - loss: 0.2812 - val_Recall: 0.8874 - val_loss: 0.1532
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9139 - loss: 0.3000 - val_Recall: 0.8874 - val_loss: 0.1237
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9059 - loss: 0.3181 - val_Recall: 0.8829 - val_loss: 0.1157
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9000 - loss: 0.3310 - val_Recall: 0.8964 - val_loss: 0.1177
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9204 - loss: 0.3086 - val_Recall: 0.8919 - val_loss: 0.1428
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9186 - loss: 0.2842 - val_Recall: 0.9009 - val_loss: 0.0995
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.9037 - loss: 0.3311 - val_Recall: 0.8919 - val_loss: 0.1188
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.9261 - loss: 0.2785 - val_Recall: 0.9009 - val_loss: 0.1366
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9140 - loss: 0.3232 - val_Recall: 0.9009 - val_loss: 0.1190
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9317 - loss: 0.2556 - val_Recall: 0.9009 - val_loss: 0.1226
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9123 - loss: 0.2820 - val_Recall: 0.8964 - val_loss: 0.1103
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9277 - loss: 0.2615 - val_Recall: 0.8874 - val_loss: 0.1128
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9064 - loss: 0.2921 - val_Recall: 0.8964 - val_loss: 0.1212
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9305 - loss: 0.2556 - val_Recall: 0.8964 - val_loss: 0.1106
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9114 - loss: 0.2911 - val_Recall: 0.8874 - val_loss: 0.1053
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - Recall: 0.9153 - loss: 0.2855 - val_Recall: 0.8919 - val_loss: 0.0979
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9260 - loss: 0.2578 - val_Recall: 0.8919 - val_loss: 0.1319

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  103.72944831848145

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_3 on training and validation data respectively.

# %%
model_3_train_perf = model_performance_classification(model_3,X_train,y_train)
model_3_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.990125  0.960324   0.947081  0.953592

# %%
model_3_val_perf = model_performance_classification(model_3,X_val,y_val)
model_3_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.98675  0.942108   0.932943   0.93747

# %%
y_train_pred_3 = model_3.predict(X_train)
y_val_pred_3 = model_3.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# Lets check the classification report of model_3 on training and validation data respectively.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_3 = classification_report(y_train,y_train_pred_3 > 0.5)
print(cr_train_model_3)
# Out:
# Classification Report - Train data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99     15112
#          1.0       0.90      0.93      0.91       888
#
#     accuracy                           0.99     16000
#    macro avg       0.95      0.96      0.95     16000
# weighted avg       0.99      0.99      0.99     16000

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_3 = classification_report(y_val,y_val_pred_3 > 0.5)
print(cr_val_model_3)
# Out:
# Classification Report - Validation data Model_3
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.99      0.99      3778
#          1.0       0.87      0.89      0.88       222
#
#     accuracy                           0.99      4000
#    macro avg       0.93      0.94      0.94      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 4

# %% [markdown]
# Since we have used only SGD optimizer till now, let's use another kind of optimizer and observe its impact on the model performmance.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
model_4 = Sequential()
model_4.add(Dense(128,activation="relu",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(64,activation="relu")) # Complete the code to define the number of neurons and activation function
model_4.add(Dense(1,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_4.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │         5,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,569 (53.00 KB)
#  Trainable params: 13,569 (53.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optimizer = tf.keras.optimizers.Adam()    # defining Adam as the optimizer to be used
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_4.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_4.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()
# Out:
# Epoch 1/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - Recall: 0.5654 - loss: 0.1345 - val_Recall: 0.8288 - val_loss: 0.0629
# Epoch 2/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - Recall: 0.8481 - loss: 0.0523 - val_Recall: 0.8378 - val_loss: 0.0583
# Epoch 3/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8679 - loss: 0.0443 - val_Recall: 0.8378 - val_loss: 0.0573
# Epoch 4/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.8754 - loss: 0.0405 - val_Recall: 0.8739 - val_loss: 0.0589
# Epoch 5/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.8912 - loss: 0.0384 - val_Recall: 0.8739 - val_loss: 0.0582
# Epoch 6/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9124 - loss: 0.0317 - val_Recall: 0.8739 - val_loss: 0.0588
# Epoch 7/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9097 - loss: 0.0304 - val_Recall: 0.8604 - val_loss: 0.0576
# Epoch 8/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9055 - loss: 0.0322 - val_Recall: 0.8649 - val_loss: 0.0596
# Epoch 9/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8725 - loss: 0.0403 - val_Recall: 0.8649 - val_loss: 0.0605
# Epoch 10/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.8925 - loss: 0.0335 - val_Recall: 0.8739 - val_loss: 0.0599
# Epoch 11/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9127 - loss: 0.0290 - val_Recall: 0.8784 - val_loss: 0.0628
# Epoch 12/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9208 - loss: 0.0261 - val_Recall: 0.8784 - val_loss: 0.0612
# Epoch 13/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.8845 - loss: 0.0333 - val_Recall: 0.8784 - val_loss: 0.0634
# Epoch 14/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9016 - loss: 0.0264 - val_Recall: 0.8829 - val_loss: 0.0675
# Epoch 15/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9201 - loss: 0.0227 - val_Recall: 0.8694 - val_loss: 0.0738
# Epoch 16/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9168 - loss: 0.0249 - val_Recall: 0.8829 - val_loss: 0.0659
# Epoch 17/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9166 - loss: 0.0235 - val_Recall: 0.8964 - val_loss: 0.0669
# Epoch 18/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9314 - loss: 0.0211 - val_Recall: 0.8378 - val_loss: 0.0741
# Epoch 19/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9070 - loss: 0.0240 - val_Recall: 0.8604 - val_loss: 0.0735
# Epoch 20/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9244 - loss: 0.0207 - val_Recall: 0.8694 - val_loss: 0.0694
# Epoch 21/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9108 - loss: 0.0254 - val_Recall: 0.8604 - val_loss: 0.0792
# Epoch 22/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.9141 - loss: 0.0224 - val_Recall: 0.8694 - val_loss: 0.0791
# Epoch 23/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - Recall: 0.9191 - loss: 0.0197 - val_Recall: 0.8694 - val_loss: 0.0756
# Epoch 24/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9133 - loss: 0.0226 - val_Recall: 0.8784 - val_loss: 0.0821
# Epoch 25/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9029 - loss: 0.0236 - val_Recall: 0.8604 - val_loss: 0.0793
# Epoch 26/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9238 - loss: 0.0187 - val_Recall: 0.8829 - val_loss: 0.0801
# Epoch 27/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9382 - loss: 0.0166 - val_Recall: 0.8694 - val_loss: 0.0784
# Epoch 28/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - Recall: 0.9327 - loss: 0.0152 - val_Recall: 0.8604 - val_loss: 0.0862
# Epoch 29/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.9300 - loss: 0.0176 - val_Recall: 0.8829 - val_loss: 0.0855
# Epoch 30/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9206 - loss: 0.0169 - val_Recall: 0.8784 - val_loss: 0.0903
# Epoch 31/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9395 - loss: 0.0150 - val_Recall: 0.8784 - val_loss: 0.0927
# Epoch 32/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9375 - loss: 0.0127 - val_Recall: 0.8739 - val_loss: 0.0935
# Epoch 33/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9271 - loss: 0.0155 - val_Recall: 0.8649 - val_loss: 0.0955
# Epoch 34/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9210 - loss: 0.0159 - val_Recall: 0.8739 - val_loss: 0.1000
# Epoch 35/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9425 - loss: 0.0132 - val_Recall: 0.8739 - val_loss: 0.1053
# Epoch 36/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9291 - loss: 0.0155 - val_Recall: 0.8784 - val_loss: 0.0985
# Epoch 37/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.9456 - loss: 0.0128 - val_Recall: 0.8739 - val_loss: 0.0984
# Epoch 38/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9226 - loss: 0.0173 - val_Recall: 0.8739 - val_loss: 0.1069
# Epoch 39/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9354 - loss: 0.0134 - val_Recall: 0.8829 - val_loss: 0.0972
# Epoch 40/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9491 - loss: 0.0109 - val_Recall: 0.8694 - val_loss: 0.1071
# Epoch 41/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9640 - loss: 0.0077 - val_Recall: 0.8739 - val_loss: 0.1103
# Epoch 42/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9494 - loss: 0.0113 - val_Recall: 0.8694 - val_loss: 0.1121
# Epoch 43/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9509 - loss: 0.0107 - val_Recall: 0.8514 - val_loss: 0.1176
# Epoch 44/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9475 - loss: 0.0113 - val_Recall: 0.8649 - val_loss: 0.1127
# Epoch 45/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - Recall: 0.9522 - loss: 0.0091 - val_Recall: 0.8829 - val_loss: 0.1208
# Epoch 46/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - Recall: 0.9506 - loss: 0.0117 - val_Recall: 0.8649 - val_loss: 0.1191
# Epoch 47/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Recall: 0.9437 - loss: 0.0121 - val_Recall: 0.8784 - val_loss: 0.1299
# Epoch 48/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9490 - loss: 0.0109 - val_Recall: 0.8559 - val_loss: 0.1225
# Epoch 49/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9560 - loss: 0.0105 - val_Recall: 0.8739 - val_loss: 0.1207
# Epoch 50/50
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Recall: 0.9622 - loss: 0.0074 - val_Recall: 0.8559 - val_loss: 0.1266

# %%
print("Time taken in seconds ",end-start)
# Out:
# Time taken in seconds  92.95161318778992

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance ofr model_4 on training and validation data respectively

# %%
model_4_train_perf = model_performance_classification(model_4,X_train,y_train)
model_4_train_perf
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0  0.997812  0.980823   0.998293  0.989381

# %%
model_4_val_perf = model_performance_classification(model_4,X_val,y_val)
model_4_val_perf
# Out:
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Accuracy    Recall  Precision  F1 Score
# 0   0.99075  0.927266   0.982974  0.953196

# %%
y_train_pred_4 = model_4.predict(X_train)
y_val_pred_4 = model_4.predict(X_val)
# Out:
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# Lets check the classification report of model_4 on raining and validation data respectively.

# %%
print("Classification Report - Train data Model_4", end="\n\n")
cr_train_model_4 = classification_report(y_train,y_train_pred_4 > 0.5)
print(cr_train_model_4)
# Out:
# Classification Report - Train data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     15112
#          1.0       1.00      0.96      0.98       888
#
#     accuracy                           1.00     16000
#    macro avg       1.00      0.98      0.99     16000
# weighted avg       1.00      1.00      1.00     16000

# %%
print("Classification Report - Validation data Model_4", end="\n\n")
cr_val_model_4 = classification_report(y_val,y_val_pred_4 > 0.5)
print(cr_val_model_4)
# Out:
# Classification Report - Validation data Model_4
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      1.00      3778
#          1.0       0.97      0.86      0.91       222
#
#     accuracy                           0.99      4000
#    macro avg       0.98      0.93      0.95      4000
# weighted avg       0.99      0.99      0.99      4000

# %% [markdown]
# ## Model 5

# %% [markdown]
# This time we will add more layers and dropout while using a different optimizer.

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
#Initializing the neural network
from tensorflow.keras.layers import Dropout
model_5 = Sequential()
model_5.add(Dense(_____,activation="_____",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_5.add(Dropout(_____)) #Complete the code to define the dropout rate
model_5.add(Dense(_____,activation="____")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(_____, activation = "____")) # Complete the code to define the number of neurons and activation function
model_5.add(Dense(____,activation="____")) # Complete the code to define the number of neurons and activation function

# %%
model_5.summary()

# %%
optimizer = tf.keras.optimizers.Adam()    # defining Adam as the optimizer to be used
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_5.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_5.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs)
end=time.time()

# %%
print("Time taken in seconds ",end-start)

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_5 on the training and validation data.

# %%
model_5_train_perf = model_performance_classification(model_5,X_train,y_train)
model_5_train_perf

# %%
model_5_val_perf = model_performance_classification(model_5,X_val,y_val)
model_5_val_perf

# %%
y_train_pred_5 = model_5.predict(X_train)
y_val_pred_5 = model_5.predict(X_val)

# %% [markdown]
# Lets check the classification report of model_5 on training and validation data.

# %%
print("Classification Report - Train data Model_2", end="\n\n")
cr_train_model_5 = classification_report(y_train,y_train_pred_5 > 0.5)
print(cr_train_model_5)

# %%
print("Classification Report - Validation data Model_2", end="\n\n")
cr_val_model_5 = classification_report(y_val,y_val_pred_5 > 0.5)
print(cr_val_model_5)

# %% [markdown]
# ## Model 6

# %% [markdown]
# Let's see how does the model performance change when the model gives higher importance to the minority class

# %%
# clears the current Keras session, resetting all layers and models previously created, freeing up memory and resources.
tf.keras.backend.clear_session()

# %%
model_6 = Sequential()
model_6.add(Dense(____,activation="____",input_dim=X_train.shape[1])) # Complete the code to define the number of neurons and activation function
model_6.add(Dropout(____)) # Complete the code to define the dropout rate
model_6.add(Dense(_____,activation="_____")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(_____, activation = "_____")) # Complete the code to define the number of neurons and activation function
model_6.add(Dense(_____,activation="sigmoid")) # Complete the code to define the number of neurons in the output layer

# %%
model_6.summary()

# %%
optimizer = tf.keras.optimizers.SGD()
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['accuracy']) ## Uncomment this line in case the metric of choice is Accuracy
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Precision']) ## Uncomment this line in case the metric of choice is Precision
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['Recall']) ## Uncomment this line in case the metric of choice is Recall
# model_6.compile(loss='binary_crossentropy', optimizer=optimizer, metrics = ['f1_score']) ## Uncomment this line in case the metric of choice is F1 Score

# %%
start = time.time()
history = model_3.fit(X_train, y_train, validation_data=(X_val,y_val) , batch_size=batch_size, epochs=epochs,class_weight=_____, ) # Complete the code such that the model is biased towards the minority class
end=time.time()

# %%
print("Time taken in seconds ",end-start)

# %%
plot(history,'loss')

# %% [markdown]
# Lets check the model performance of model_6 on training and validation data.

# %%
model_6_train_perf = model_performance_classification(model_6,X_train,y_train)
model_6_train_perf

# %%
model_6_val_perf = model_performance_classification(model_6,X_val,y_val)
model_6_val_perf

# %%
y_train_pred_6 = model_6.predict(X_train)
y_val_pred_6 = model_6.predict(X_val)

# %% [markdown]
# Lets check the classification report of model_6 on both training and validation data.

# %%
print("Classification Report - Train data Model_3", end="\n\n")
cr_train_model_6 = classification_report(y_train,y_train_pred_6 > 0.5)
print(cr_train_model_6)

# %%
print("Classification Report - Validation data Model_3", end="\n\n")
cr_val_model_6 = classification_report(y_val,y_val_pred_6 > 0.5)
print(cr_val_model_6)

# %% [markdown]
# # **Model Performance Comparison and Final Model Selection**

# %% [markdown]
# Now, in order to select the final model, we will compare the performances of all the models for the training and test sets.

# %% [markdown]
# **Training Performance Comparison**

# %%
# training performance comparison

models_train_comp_df = pd.concat(
    [
        model_0_train_perf.T,
        model_1_train_perf.T,
        model_2_train_perf.T,
        model_3_train_perf.T,
        model_4_train_perf.T,
        model_5_train_perf.T,
        model_6_train_perf.T

    ],
    axis=1,
)
models_train_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Training set performance comparison:")
models_train_comp_df

# %% [markdown]
# **Validation Performance Comparison**

# %%
# Validation performance comparison

models_val_comp_df = pd.concat(
    [
        model_0_val_perf.T,
        model_1_val_perf.T,
        model_2_val_perf.T,
        model_3_val_perf.T,
        model_4_val_perf.T,
        model_5_val_perf.T,
        model_6_val_perf.T

    ],
    axis=1,
)
models_val_comp_df.columns = [
    "Model 0",
    "Model 1",
    "Model 2",
    "Model 3",
    "Model 4",
    "Model 5",
    "Model 6"
]
print("Validation set performance comparison:")
models_val_comp_df

# %% [markdown]
# **Checking the performance of the best model on the test set**

# %%
# best_model = model_0 ## Uncomment this line in case the best model is model_0
# best_model = model_1 ## Uncomment this line in case the best model is model_1
# best_model = model_2 ## Uncomment this line in case the best model is model_2
# best_model = model_3 ## Uncomment this line in case the best model is model_3
# best_model = model_4 ## Uncomment this line in case the best model is model_4
# best_model = model_5 ## Uncomment this line in case the best model is model_5
# best_model = model_6 ## Uncomment this line in case the best model is model_6

# %%
# Test set performance for the best model
best_model_test_perf = model_performance_classification(best_model,X_test,y_test)
best_model_test_perf

# %%
y_test_pred_best = best_model.predict(X_test)

cr_test_best_model = classification_report(y_test, y_test_pred_best>0.5) # Check the classification report of best model on test data.
print(cr_test_best_model)

# %% [markdown]
# # **Actionable Insights and Recommendations**

# %% [markdown]
# - Write down actionable insights here

# %% [markdown]
# - Write down business recommendations here
